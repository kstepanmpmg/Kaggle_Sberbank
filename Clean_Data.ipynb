# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
from sklearn import model_selection, preprocessing

pd.options.display.max_columns = 300
# %matplotlib inline  
pd.options.display.max_rows = 300

# %%
df_train = pd.read_csv('train.csv', parse_dates=['timestamp'])
df_test = pd.read_csv('test.csv', parse_dates=['timestamp'])
df_macro = pd.read_csv('macro.csv', parse_dates=['timestamp'])

# %%
for c in df_train.columns:
    if df_train[c].dtype == 'object':
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(df_train[c].values)) 
        df_train[c] = lbl.transform(list(df_train[c].values))
        #x_train.drop(c,axis=1,inplace=True)

# %%
df_train.shape
# Out:
# (30471, 292)

# %%
variance = df_train.var()

# %%
variance.shape
# Out:
# (291,)

# %%
pd.DataFrame(variance).reset_index().sort(0)
# Out:
# /home/tseidakhmetov/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                                      index             0
# 171                       mosque_count_500  4.866144e-03
# 34                     oil_chemistry_raion  9.620105e-03
# 15                             indust_part  1.408673e-02
# 194                      mosque_count_1000  1.879905e-02
# 113                        big_road1_1line  2.497480e-02
# 38                   nuclear_reactor_raion  2.752078e-02
# 117                         railroad_1line  2.844861e-02
# 14                         green_zone_part  3.065656e-02
# 168              cafe_count_500_price_high  3.320161e-02
# 36                 railroad_terminal_raion  3.589263e-02
# 217                      mosque_count_1500  3.637831e-02
# 32               thermal_power_plant_raion  5.133636e-02
# 28                  culture_objects_top_25  5.927171e-02
# 33                      incineration_raion  7.023198e-02
# 105                            water_1line  7.081594e-02
# 240                      mosque_count_2000  8.030060e-02
# 37                        big_market_raion  8.403830e-02
# 91                           green_zone_km  8.904382e-02
# 39                detention_facility_raion  8.992155e-02
# 191             cafe_count_1000_price_high  1.105591e-01
# 22   school_education_centers_top_20_raion  1.111078e-01
# 172                      leisure_count_500  1.492995e-01
# 174                       market_count_500  1.608326e-01
# 104                               water_km  1.891544e-01
# 25                 university_top_20_raion  1.969551e-01
# 263                      mosque_count_3000  2.005387e-01
# 35                         radiation_raion  2.294914e-01
# 10                            product_type  2.308956e-01
# 286                      mosque_count_5000  3.712086e-01
# 167              cafe_count_500_price_4000  4.749739e-01
# 92                           industrial_km  5.154568e-01
# 197                      market_count_1000  5.375993e-01
# 145                    church_synagogue_km  5.608149e-01
# 150                            catering_km  6.937589e-01
# 7                                 num_room  7.255709e-01
# 9                                    state  7.746606e-01
# 214             cafe_count_1500_price_high  8.242276e-01
# 220                      market_count_1500  1.255496e+00
# 74                        build_count_foam  1.283740e+00
# 169                   big_church_count_500  1.404908e+00
# 151                                ecology  1.499188e+00
# 156                          trc_count_500  1.552739e+00
# 102            public_transport_station_km  1.619227e+00
# 111                           big_road1_km  1.682698e+00
# 162                cafe_count_500_na_price  1.845157e+00
# 243                      market_count_2000  2.058659e+00
# 94                             cemetery_km  2.105606e+00
# 5                                 material  2.193817e+00
# 24                healthcare_centers_raion  2.228759e+00
# 29            culture_objects_top_25_raion  2.281583e+00
# 142                additional_education_km  2.329345e+00
# 76                         build_count_mix  2.341286e+00
# 130                             fitness_km  2.375992e+00
# 173                        sport_count_500  2.685695e+00
# 237             cafe_count_2000_price_high  2.851123e+00
# 195                     leisure_count_1000  3.313324e+00
# 114                           big_road2_km  3.501891e+00
# 116                            railroad_km  3.892012e+00
# 88                         kindergarten_km  4.502696e+00
# 166              cafe_count_500_price_2500  4.568354e+00
# 170                       church_count_500  4.682139e+00
# 140                    shopping_centers_km  5.079431e+00
# 164              cafe_count_500_price_1000  5.146009e+00
# 266                      market_count_3000  5.159891e+00
# 154                       office_count_500  5.213781e+00
# 141                              office_km  5.319692e+00
# 165              cafe_count_500_price_1500  5.375596e+00
# 192                  big_church_count_1000  6.213596e+00
# 260             cafe_count_3000_price_high  7.703395e+00
# 135                      hospice_morgue_km  8.716726e+00
# 144                          big_church_km  8.921790e+00
# 18       preschool_education_centers_raion  8.962810e+00
# 143                           preschool_km  9.324476e+00
# 89                               school_km  9.352249e+00
# 163               cafe_count_500_price_500  9.366255e+00
# 185               cafe_count_1000_na_price  1.002121e+01
# 179                         trc_count_1000  1.053864e+01
# 27              additional_education_raion  1.082448e+01
# 196                       sport_count_1000  1.110394e+01
# 218                     leisure_count_1500  1.120683e+01
# 21          school_education_centers_raion  1.186875e+01
# 129                         market_shop_km  1.188551e+01
# 121                        ID_bus_terminal  1.437049e+01
# 96                railroad_station_walk_km  1.471765e+01
# 99                railroad_station_avto_km  1.531732e+01
# 190             cafe_count_1000_price_4000  1.568086e+01
# 90                                 park_km  1.572410e+01
# 137                   public_healthcare_km  1.885127e+01
# 202                         trc_count_1500  2.011353e+01
# 125             power_transmission_line_km  2.072498e+01
# 131                           swim_pool_km  2.140024e+01
# 132                            ice_rink_km  2.178888e+01
# 30                  shopping_centers_raion  2.248478e+01
# 100              railroad_station_avto_min  2.298848e+01
# 127                                  ts_km  2.308070e+01
# 289                      market_count_5000  2.390446e+01
# 139                          workplaces_km  2.408416e+01
# 193                      church_count_1000  2.609543e+01
# 106                                mkad_km  2.644522e+01
# 149                          exhibition_km  2.813461e+01
# 3                                    floor  2.830228e+01
# 134                          basketball_km  2.911108e+01
# 283             cafe_count_5000_price_high  2.936347e+01
# 124                           radiation_km  3.130813e+01
# 126                 thermal_power_plant_km  3.157687e+01
# 268                         prom_part_5000  3.213470e+01
# 148                              museum_km  3.252201e+01
# 219                       sport_count_1500  3.314061e+01
# 87                           metro_km_walk  3.335364e+01
# 146                              mosque_km  3.341330e+01
# 85                           metro_km_avto  3.373788e+01
# 208               cafe_count_1500_na_price  3.571069e+01
# 225                         trc_count_2000  4.021284e+01
# 215                  big_church_count_1500  4.197626e+01
# 84                          metro_min_avto  4.294856e+01
# 26                     sport_objects_raion  4.319095e+01
# 138                          university_km  4.531288e+01
# 213             cafe_count_1500_price_4000  4.541835e+01
# 4                                max_floor  4.565097e+01
# 95                         incineration_km  4.610015e+01
# 93                      water_treatment_km  4.951024e+01
# 147                             theater_km  5.058458e+01
# 241                     leisure_count_2000  5.163514e+01
# 123                     nuclear_reactor_km  5.255896e+01
# 120                   bus_terminal_avto_km  5.375822e+01
# 189             cafe_count_1000_price_2500  5.639727e+01
# 133                             stadium_km  5.840073e+01
# 245                         prom_part_3000  6.301570e+01
# 107                                 ttk_km  6.507295e+01
# 108                             sadovoe_km  6.960835e+01
# 110                             kremlin_km  7.126676e+01
# 109                         bulvar_ring_km  7.183142e+01
# 128                          big_market_km  7.220189e+01
# 177                      office_count_1000  7.882632e+01
# 187             cafe_count_1000_price_1000  8.461165e+01
# 242                       sport_count_2000  8.497834e+01
# 222                         prom_part_2000  9.296746e+01
# 236             cafe_count_2000_price_4000  9.452798e+01
# 216                      church_count_1500  9.482136e+01
# 238                  big_church_count_2000  1.000011e+02
# 231               cafe_count_2000_na_price  1.045153e+02
# 118                     zd_vokzaly_avto_km  1.061025e+02
# 122                       oil_chemistry_km  1.081498e+02
# 188             cafe_count_1000_price_1500  1.102285e+02
# 248                         trc_count_3000  1.191247e+02
# 199                         prom_part_1500  1.205490e+02
# 136                  detention_facility_km  1.227632e+02
# 267                        green_part_5000  1.256298e+02
# 158                         cafe_count_500  1.273268e+02
# 112                           ID_big_road1  1.287935e+02
# 176                         prom_part_1000  1.326579e+02
# 153                          prom_part_500  1.332577e+02
# 264                     leisure_count_3000  1.739431e+02
# 75                        build_count_slag  1.749650e+02
# 212             cafe_count_1500_price_2500  1.825632e+02
# 186              cafe_count_1000_price_500  1.921121e+02
# 244                        green_part_3000  1.964842e+02
# 221                        green_part_2000  2.014611e+02
# 198                        green_part_1500  2.016477e+02
# 175                        green_part_1000  2.106842e+02
# 70                       build_count_frame  2.228134e+02
# 103      public_transport_station_min_walk  2.331687e+02
# 261                  big_church_count_3000  2.375821e+02
# 239                      church_count_2000  2.400656e+02
# 152                         green_part_500  2.576384e+02
# 259             cafe_count_3000_price_4000  2.850872e+02
# 115                           ID_big_road2  3.023885e+02
# 254               cafe_count_3000_na_price  3.327852e+02
# 265                       sport_count_3000  3.550913e+02
# 72                    build_count_monolith  3.716797e+02
# 287                     leisure_count_5000  4.235669e+02
# 200                      office_count_1500  4.398402e+02
# 210             cafe_count_1500_price_1000  4.897558e+02
# 235             cafe_count_2000_price_2500  5.395456e+02
# 31                            office_raion  5.539882e+02
# 271                         trc_count_5000  5.723602e+02
# 211             cafe_count_1500_price_1500  5.823337e+02
# 209              cafe_count_1500_price_500  6.195077e+02
# 262                      church_count_3000  6.648786e+02
# 98                ID_railroad_station_walk  7.709654e+02
# 8                                 kitch_sq  7.989656e+02
# 282             cafe_count_5000_price_4000  8.057468e+02
# 284                  big_church_count_5000  8.478968e+02
# 277               cafe_count_5000_na_price  1.106830e+03
# 101               ID_railroad_station_avto  1.182880e+03
# 119                   ID_railroad_terminal  1.248696e+03
# 1                                  full_sq  1.446394e+03
# 223                      office_count_2000  1.499475e+03
# 232              cafe_count_2000_price_500  1.533425e+03
# 234             cafe_count_2000_price_1500  1.537091e+03
# 11                                sub_area  1.540930e+03
# 233             cafe_count_2000_price_1000  1.541173e+03
# 258             cafe_count_3000_price_2500  1.704204e+03
# 97               railroad_station_walk_min  2.119341e+03
# 288                       sport_count_5000  2.143010e+03
# 68                       build_count_block  2.203141e+03
# 285                      church_count_5000  2.241827e+03
# 181                        cafe_count_1000  2.268675e+03
# 2                                  life_sq  2.733798e+03
# 83                                ID_metro  3.014260e+03
# 81                   build_count_1971-1995  3.349386e+03
# 78                 build_count_before_1920  3.718959e+03
# 79                   build_count_1921-1945  3.907783e+03
# 86                          metro_min_walk  4.802924e+03
# 256             cafe_count_3000_price_1000  4.834238e+03
# 257             cafe_count_3000_price_1500  5.020535e+03
# 255              cafe_count_3000_price_500  5.159045e+03
# 281             cafe_count_5000_price_2500  5.397196e+03
# 246                      office_count_3000  6.618168e+03
# 73                       build_count_panel  7.789776e+03
# 204                        cafe_count_1500  9.495665e+03
# 82                  build_count_after_1995  1.304672e+04
# 280             cafe_count_5000_price_1500  1.539502e+04
# 80                   build_count_1946-1970  1.573214e+04
# 278              cafe_count_5000_price_500  1.585952e+04
# 279             cafe_count_5000_price_1000  1.591828e+04
# 69                        build_count_wood  1.606312e+04
# 71                       build_count_brick  1.667208e+04
# 274            cafe_sum_5000_min_price_avg  2.322849e+04
# 269                      office_count_5000  2.413094e+04
# 227                        cafe_count_2000  2.612554e+04
# 205            cafe_sum_1500_min_price_avg  3.696385e+04
# 276                    cafe_avg_price_5000  3.768168e+04
# 228            cafe_sum_2000_min_price_avg  3.974937e+04
# 251            cafe_sum_3000_min_price_avg  5.017901e+04
# 182            cafe_sum_1000_min_price_avg  5.036898e+04
# 275            cafe_sum_5000_max_price_avg  5.579407e+04
# 207                    cafe_avg_price_1500  5.792161e+04
# 230                    cafe_avg_price_2000  6.250718e+04
# 67    raion_build_count_with_material_info  7.723064e+04
# 77   raion_build_count_with_builddate_info  7.723788e+04
# 184                    cafe_avg_price_1000  7.987837e+04
# 253                    cafe_avg_price_3000  8.303817e+04
# 250                        cafe_count_3000  8.417822e+04
# 206            cafe_sum_1500_max_price_avg  8.485444e+04
# 229            cafe_sum_2000_max_price_avg  9.170376e+04
# 159             cafe_sum_500_min_price_avg  1.163465e+05
# 183            cafe_sum_1000_max_price_avg  1.177394e+05
# 252            cafe_sum_3000_max_price_avg  1.248207e+05
# 161                     cafe_avg_price_500  1.870696e+05
# 273                        cafe_count_5000  2.647500e+05
# 160             cafe_sum_500_max_price_avg  2.772435e+05
# 23                     hospital_beds_raion  1.117281e+06
# 54                              0_6_female  3.409924e+06
# 57                             7_14_female  3.768958e+06
# 53                                0_6_male  3.893600e+06
# 56                               7_14_male  4.221059e+06
# 17                         preschool_quota  4.707857e+06
# 66                             0_13_female  1.250971e+07
# 65                               0_13_male  1.414325e+07
# 16                      children_preschool  1.456663e+07
# 52                                 0_6_all  1.456663e+07
# 55                                7_14_all  1.591723e+07
# 19                         children_school  1.591723e+07
# 45                            young_female  1.616479e+07
# 50                              ekder_male  1.659608e+07
# 44                              young_male  1.827937e+07
# 20                            school_quota  1.840182e+07
# 60                             0_17_female  2.017568e+07
# 59                               0_17_male  2.274902e+07
# 64                                0_13_all  5.314420e+07
# 43                               young_all  6.869024e+07
# 0                                       id  7.737844e+07
# 51                            ekder_female  8.361871e+07
# 58                                0_17_all  8.561887e+07
# 49                               ekder_all  1.735733e+08
# 48                             work_female  3.475664e+08
# 47                               work_male  3.586916e+08
# 62                              16_29_male  8.584108e+08
# 63                            16_29_female  9.677684e+08
# 46                                work_all  1.405017e+09
# 155                         office_sqm_500  1.815614e+09
# 13                             raion_popul  3.349086e+09
# 61                               16_29_all  3.645928e+09
# 157                            trc_sqm_500  6.655322e+09
# 41                                  male_f  1.675589e+10
# 178                        office_sqm_1000  2.069368e+10
# 180                           trc_sqm_1000  2.258397e+10
# 42                                female_f  2.360245e+10
# 6                               build_year  2.383559e+10
# 203                           trc_sqm_1500  4.521201e+10
# 40                                full_all  8.010322e+10
# 226                           trc_sqm_2000  8.458297e+10
# 201                        office_sqm_1500  9.101349e+10
# 249                           trc_sqm_3000  2.206477e+11
# 224                        office_sqm_2000  2.536496e+11
# 272                           trc_sqm_5000  1.009643e+12
# 247                        office_sqm_3000  1.115406e+12
# 270                        office_sqm_5000  5.304051e+12
# 290                              price_doc  2.284946e+13
# 12                                  area_m  4.264063e+14
